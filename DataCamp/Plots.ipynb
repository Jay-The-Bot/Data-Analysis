# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4], [10, 20, 30 ,40])
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.title('The Graph')
plt.show()

# %%
plt.scatter([1, 2, 3, 4], [10, 20 ,30, 40])
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.title('The Graph')
plt.show()
